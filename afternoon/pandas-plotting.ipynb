# %% [markdown]
# # Introduction to Data Analysis and Plotting in Python
#
# * Introduce Pandas for data handling and analysis
# * Use Matplotlib, Seaborn and Bokeh for visualization

# %% [markdown]
# ## What is pandas?
#
# * Built on top of NumPy
#
# * Provides structures for working with data (`Series`, `DataFrame`)
#
# * Data structures have **methods** for manipulating data eg. indexing, sorting, grouping, filling in missing data
#
# * Pandas does not provide modeling tools eg. regression, prediction
#     * These tools are found in packages such as `scikit-learn` and `statsmodels`, which are built on top of pandas

# %% [markdown]
# ## DataFrames
#
# A `DataFrame` combines multiple 'columns' of data into a two-dimensional object, similar to a spreadsheet
# * Data does not have to be of the same type

# %%
from IPython.display import Image
Image('./dataframe.jpg')

# %% [markdown]
# We will create a `DataFrame` by reading in a CSV file and assigning it to the variable name `majors`

# %% [markdown]
# ### Info on the data set
#
# * The data come from ['The Economic Guide to Picking a College Major'](https://fivethirtyeight.com/features/the-economic-guide-to-picking-a-college-major/), Fivethirtyeight magazine
# * Other interesting datasets can be found on the Fivethirtyeight GitHub: https://github.com/fivethirtyeight/data/

# %%
import pandas as pd

majors = pd.read_csv('recent-grads.csv')
majors.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# 0      ...              270                  1207          37
# 1      ...              170                   388          85
# 2      ...              133                   340          16
# 3      ...              150                   692          40
# 4      ...             5180                 16697        1672
#
#    Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0           0.018381  110000  95000  125000          1534               364
# 1           0.117241   75000  55000   90000           350               257
# 2           0.024096   73000  50000  105000           456               176
# 3           0.050125   70000  43000   80000           529               102
# 4           0.061098   65000  50000   75000         18314              4440
#
#    Low_wage_jobs
# 0            193
# 1             50
# 2              0
# 3              0
# 4            972
#
# [5 rows x 21 columns]

# %%
majors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# Non_college_jobs        173 non-null int64
# Low_wage_jobs           173 non-null int64
# dtypes: float64(5), int64(14), object(2)
# memory usage: 28.5+ KB

# %% [markdown]
# We can access individual columns of data, returning a `Series`

# %%
majors.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
majors['Major'].head()
# Out:
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# Name: Major, dtype: object

# %% [markdown]
# We can also select multiple columns, returning a new dataframe

# %%
majors[['Major', 'ShareWomen']].head()
# Out:
#                                        Major  ShareWomen
# 0                      PETROLEUM ENGINEERING    0.120564
# 1             MINING AND MINERAL ENGINEERING    0.101852
# 2                  METALLURGICAL ENGINEERING    0.153037
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    0.107313
# 4                       CHEMICAL ENGINEERING    0.341631

# %% [markdown]
# We can add a new column to our dataframe like so

# %%
majors['Employment rate'] = majors['Employed'] / majors['Total']
majors.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#         ...         Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       ...                         1207          37           0.018381
# 1       ...                          388          85           0.117241
# 2       ...                          340          16           0.024096
# 3       ...                          692          40           0.050125
# 4       ...                        16697        1672           0.061098
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs  \
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972
#
#    Employment rate
# 0         0.844805
# 1         0.846561
# 2         0.757009
# 3         0.602544
# 4         0.796466
#
# [5 rows x 22 columns]

# %% [markdown]
# #### A note on efficiency!
#
# * As mentioned earlier, Pandas is built on NumPy
# * We can take advantage of NumPy's optimized code for tasks suited to vectorization

# %%
del majors['Employment rate']

# %timeit majors['Employment rate'] = majors['Employed'] / majors['Total']
# Out:
# 230 µs ± 6.69 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
del majors['Employment rate']

# %timeit majors['Employment rate'] = majors['Employed'].values / majors['Total'].values
# Out:
# 132 µs ± 3.16 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# If we want to know the average unemployment rate...

# %%
majors['Unemployment_rate'].median() * 100
# Out:
# 6.796076599999999

# %% [markdown]
# `.describe()` returns useful summary statistics

# %%
majors['Unemployment_rate'].describe()
# Out:
# count    173.000000
# mean       0.068191
# std        0.030331
# min        0.000000
# 25%        0.050306
# 50%        0.067961
# 75%        0.087557
# max        0.177226
# Name: Unemployment_rate, dtype: float64

# %% [markdown]
# Pandas also provides a simple way to generate matplotlib plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

majors.plot(x='ShareWomen', y='Median', kind='scatter', figsize=(10, 8), color='red')
plt.xlabel('Share of women')
plt.ylabel('Median salary')
plt.show()

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Find the mean number of full-time and part-time workers across majors

# %% [markdown]
# #### Find the median number of people in low wage jobs

# %% [markdown]
# #### Create a table of summary statistics for the unemployment and employment rates

# %% [markdown]
# #### Create a table of summary statistics for major's categories

# %% [markdown]
# #### Create a new variable equal to the proportion of workers who are part time
#
# #### Plot the part time rate against the share of women

# %% [markdown]
# ## Selecting and filtering

# %% [markdown]
# We can use integer slicing to select rows as follows

# %%
majors[2:10:2]
# Out:
#    Rank  Major_code                      Major    Total      Men    Women  \
# 2     3        2415  METALLURGICAL ENGINEERING    856.0    725.0    131.0
# 4     5        2405       CHEMICAL ENGINEERING  32260.0  21239.0  11021.0
# 6     7        6202          ACTUARIAL SCIENCE   3777.0   2110.0   1667.0
# 8     9        2414     MECHANICAL ENGINEERING  91227.0  80320.0  10907.0
#
#   Major_category  ShareWomen  Sample_size  Employed       ...         \
# 2    Engineering    0.153037            3       648       ...
# 4    Engineering    0.341631          289     25694       ...
# 6       Business    0.441356           51      2912       ...
# 8    Engineering    0.119559         1029     76442       ...
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 2                   340          16           0.024096   73000  50000  105000
# 4                 16697        1672           0.061098   65000  50000   75000
# 6                  2482         308           0.095652   62000  53000   72000
# 8                 54639        4650           0.057342   60000  48000   70000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs  Employment rate
# 2           456               176              0         0.757009
# 4         18314              4440            972         0.796466
# 6          1768               314            259         0.770982
# 8         52844             16384           3253         0.837932
#
# [4 rows x 22 columns]

# %% [markdown]
# We might want to find the majors with the highest share of women
#
# First we will sort our values by a column in the dataframe

# %%
majors.sort_values(by='ShareWomen', ascending=False)[:3]
# Out:
#      Rank  Major_code                                          Major    Total  \
# 164   165        2307                      EARLY CHILDHOOD EDUCATION  37589.0
# 163   164        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES  38279.0
# 51     52        6104                     MEDICAL ASSISTING SERVICES  11123.0
#
#         Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 164  1167.0  36422.0      Education    0.968954          342     32551
# 163  1225.0  37054.0         Health    0.967998           95     29763
# 51    803.0  10320.0         Health    0.927807           67      9168
#
#           ...         Full_time_year_round  Unemployed  Unemployment_rate  \
# 164       ...                        20748        1360           0.040105
# 163       ...                        14460        1487           0.047584
# 51        ...                         4290         407           0.042507
#
#      Median  P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs  \
# 164   28000  21000  35000         23515              7705           2868
# 163   28000  20000  40000         19957              9404           5125
# 51    42000  30000  65000          2091              6948           1270
#
#      Employment rate
# 164         0.865971
# 163         0.777528
# 51          0.824238
#
# [3 rows x 22 columns]

# %% [markdown]
# Another way to select rows is to use row labels, ie. set a row index
#
# Similar to the column labels, we can add row labels (the index)

# %%
majors.set_index('Major_code').head()
# Out:
#             Rank                                      Major    Total      Men  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING   2339.0   2057.0
# 2416           2             MINING AND MINERAL ENGINEERING    756.0    679.0
# 2415           3                  METALLURGICAL ENGINEERING    856.0    725.0
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 2405           5                       CHEMICAL ENGINEERING  32260.0  21239.0
#
#               Women Major_category  ShareWomen  Sample_size  Employed  \
# Major_code
# 2419          282.0    Engineering    0.120564           36      1976
# 2416           77.0    Engineering    0.101852            7       640
# 2415          131.0    Engineering    0.153037            3       648
# 2417          135.0    Engineering    0.107313           16       758
# 2405        11021.0    Engineering    0.341631          289     25694
#
#             Full_time       ...         Full_time_year_round  Unemployed  \
# Major_code                  ...
# 2419             1849       ...                         1207          37
# 2416              556       ...                          388          85
# 2415              558       ...                          340          16
# 2417             1069       ...                          692          40
# 2405            23170       ...                        16697        1672
#
#             Unemployment_rate  Median  P25th   P75th  College_jobs  \
# Major_code
# 2419                 0.018381  110000  95000  125000          1534
# 2416                 0.117241   75000  55000   90000           350
# 2415                 0.024096   73000  50000  105000           456
# 2417                 0.050125   70000  43000   80000           529
# 2405                 0.061098   65000  50000   75000         18314
#
#             Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 2419                     364            193         0.844805
# 2416                     257             50         0.846561
# 2415                     176              0         0.757009
# 2417                     102              0         0.602544
# 2405                    4440            972         0.796466
#
# [5 rows x 21 columns]

# %% [markdown]
# Note: we haven't actually changed the DataFrame `majors`

# %%
majors.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#         ...         Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       ...                         1207          37           0.018381
# 1       ...                          388          85           0.117241
# 2       ...                          340          16           0.024096
# 3       ...                          692          40           0.050125
# 4       ...                        16697        1672           0.061098
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs  \
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972
#
#    Employment rate
# 0         0.844805
# 1         0.846561
# 2         0.757009
# 3         0.602544
# 4         0.796466
#
# [5 rows x 22 columns]

# %% [markdown]
# Need to overwrite `majors` with the new copy

# %%
majors = majors.set_index('Major_code')   # Can also use majors.set_index('Major_code', inplace=True)
majors.head()
# Out:
#             Rank                                      Major    Total      Men  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING   2339.0   2057.0
# 2416           2             MINING AND MINERAL ENGINEERING    756.0    679.0
# 2415           3                  METALLURGICAL ENGINEERING    856.0    725.0
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 2405           5                       CHEMICAL ENGINEERING  32260.0  21239.0
#
#               Women Major_category  ShareWomen  Sample_size  Employed  \
# Major_code
# 2419          282.0    Engineering    0.120564           36      1976
# 2416           77.0    Engineering    0.101852            7       640
# 2415          131.0    Engineering    0.153037            3       648
# 2417          135.0    Engineering    0.107313           16       758
# 2405        11021.0    Engineering    0.341631          289     25694
#
#             Full_time       ...         Full_time_year_round  Unemployed  \
# Major_code                  ...
# 2419             1849       ...                         1207          37
# 2416              556       ...                          388          85
# 2415              558       ...                          340          16
# 2417             1069       ...                          692          40
# 2405            23170       ...                        16697        1672
#
#             Unemployment_rate  Median  P25th   P75th  College_jobs  \
# Major_code
# 2419                 0.018381  110000  95000  125000          1534
# 2416                 0.117241   75000  55000   90000           350
# 2415                 0.024096   73000  50000  105000           456
# 2417                 0.050125   70000  43000   80000           529
# 2405                 0.061098   65000  50000   75000         18314
#
#             Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 2419                     364            193         0.844805
# 2416                     257             50         0.846561
# 2415                     176              0         0.757009
# 2417                     102              0         0.602544
# 2405                    4440            972         0.796466
#
# [5 rows x 21 columns]

# %%
majors.loc[2405]
# Out:
# Rank                                       5
# Major                   CHEMICAL ENGINEERING
# Total                                  32260
# Men                                    21239
# Women                                  11021
# Major_category                   Engineering
# ShareWomen                          0.341631
# Sample_size                              289
# Employed                               25694
# Full_time                              23170
# Part_time                               5180
# Full_time_year_round                   16697
# Unemployed                              1672
# Unemployment_rate                  0.0610977
# Median                                 65000
# P25th                                  50000
# P75th                                  75000
# College_jobs                           18314
# Non_college_jobs                        4440
# Low_wage_jobs                            972
# Employment rate                     0.796466
# Name: 2405, dtype: object

# %%
code_list = [6102, 5001]

majors.loc[code_list]
# Out:
#             Rank                                          Major    Total  \
# Major_code
# 6102         164  COMMUNICATION DISORDERS SCIENCES AND SERVICES  38279.0
# 5001           8                     ASTRONOMY AND ASTROPHYSICS   1792.0
#
#                Men    Women     Major_category  ShareWomen  Sample_size  \
# Major_code
# 6102        1225.0  37054.0             Health    0.967998           95
# 5001         832.0    960.0  Physical Sciences    0.535714           10
#
#             Employed  Full_time       ...         Full_time_year_round  \
# Major_code                            ...
# 6102           29763      19975       ...                        14460
# 5001            1526       1085       ...                          827
#
#             Unemployed  Unemployment_rate  Median  P25th   P75th  \
# Major_code
# 6102              1487           0.047584   28000  20000   40000
# 5001                33           0.021167   62000  31500  109000
#
#             College_jobs  Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 6102               19957              9404           5125         0.777528
# 5001                 972               500            220         0.851562
#
# [2 rows x 21 columns]

# %% [markdown]
# We can also sort our index (this is recommended for efficient selecting and filtering)

# %%
majors.sort_index(inplace=True)
majors.head()
# Out:
#             Rank                                  Major    Total     Men  \
# Major_code
# 1100          65                    GENERAL AGRICULTURE  10399.0  6053.0
# 1101          64  AGRICULTURE PRODUCTION AND MANAGEMENT  14240.0  9658.0
# 1102          72                 AGRICULTURAL ECONOMICS   2439.0  1749.0
# 1103         153                        ANIMAL SCIENCES  21573.0  5347.0
# 1104          22                           FOOD SCIENCE      NaN     NaN
#
#               Women                   Major_category  ShareWomen  Sample_size  \
# Major_code
# 1100         4346.0  Agriculture & Natural Resources    0.417925          158
# 1101         4582.0  Agriculture & Natural Resources    0.321770          273
# 1102          690.0  Agriculture & Natural Resources    0.282903           44
# 1103        16226.0  Agriculture & Natural Resources    0.752144          255
# 1104            NaN  Agriculture & Natural Resources         NaN           36
#
#             Employed  Full_time       ...         Full_time_year_round  \
# Major_code                            ...
# 1100            8884       7589       ...                         5888
# 1101           12323      11119       ...                         9093
# 1102            2174       1819       ...                         1528
# 1103           17112      14479       ...                        10824
# 1104            3149       2558       ...                         1735
#
#             Unemployed  Unemployment_rate  Median  P25th  P75th  College_jobs  \
# Major_code
# 1100               178           0.019642   40000  30000  50000          2418
# 1101               649           0.050031   40000  25000  50000          1925
# 1102               182           0.077250   40000  27000  54000           535
# 1103               917           0.050862   30000  22000  40000          5443
# 1104               338           0.096931   53000  32000  70000          1183
#
#             Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 1100                    4717            839         0.854313
# 1101                    6221           1362         0.865379
# 1102                     893             94         0.891349
# 1103                    9571           2125         0.793214
# 1104                    1274            485              NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Alternatively, we can filter our dataframe (select rows) using *boolean conditions*

# %%
majors['Major_category'] == 'Arts'
# Out:
# Major_code
# 1100    False
# 1101    False
# 1102    False
# 1103    False
# 1104    False
# 1105    False
# 1106    False
# 1199    False
# 1301    False
# 1302    False
# 1303    False
# 1401    False
# 1501    False
# 1901    False
# 1902    False
# 1903    False
# 1904    False
# 2001    False
# 2100    False
# 2101    False
# 2102    False
# 2105    False
# 2106    False
# 2107    False
# 2201    False
# 2300    False
# 2301    False
# 2303    False
# 2304    False
# 2305    False
#         ...
# 6005     True
# 6006    False
# 6007     True
# 6099     True
# 6100    False
# 6102    False
# 6103    False
# 6104    False
# 6105    False
# 6106    False
# 6107    False
# 6108    False
# 6109    False
# 6110    False
# 6199    False
# 6200    False
# 6201    False
# 6202    False
# 6203    False
# 6204    False
# 6205    False
# 6206    False
# 6207    False
# 6209    False
# 6210    False
# 6211    False
# 6212    False
# 6299    False
# 6402    False
# 6403    False
# Name: Major_category, Length: 173, dtype: bool

# %% [markdown]
# Selecting rows with this boolean condition will return only rows of the dataframe where `Major_cateogory == 'Business'` is `True`

# %%
majors[majors['Major_category'] == 'Arts']
# Out:
#             Rank                              Major     Total      Men  \
# Major_code
# 6000         150                          FINE ARTS   74440.0  24786.0
# 6001         167             DRAMA AND THEATER ARTS   43249.0  14440.0
# 6002         147                              MUSIC   60633.0  29909.0
# 6003         154         VISUAL AND PERFORMING ARTS   16250.0   4133.0
# 6004          96  COMMERCIAL ART AND GRAPHIC DESIGN  103480.0  32041.0
# 6005         142   FILM VIDEO AND PHOTOGRAPHIC ARTS   38761.0  22357.0
# 6007         160                        STUDIO ARTS   16977.0   4754.0
# 6099          33            MISCELLANEOUS FINE ARTS    3340.0   1970.0
#
#               Women Major_category  ShareWomen  Sample_size  Employed  \
# Major_code
# 6000        49654.0           Arts    0.667034          623     59679
# 6001        28809.0           Arts    0.666119          357     36165
# 6002        30724.0           Arts    0.506721          419     47662
# 6003        12117.0           Arts    0.745662          132     12870
# 6004        71439.0           Arts    0.690365         1186     83483
# 6005        16404.0           Arts    0.423209          331     31433
# 6007        12223.0           Arts    0.719974          182     13908
# 6099         1370.0           Arts    0.410180           30      2914
#
#             Full_time       ...         Full_time_year_round  Unemployed  \
# Major_code                  ...
# 6000            42764       ...                        31877        5486
# 6001            25147       ...                        16891        3040
# 6002            29010       ...                        21425        3918
# 6003             8447       ...                         6322        1465
# 6004            67448       ...                        52243        8947
# 6005            22457       ...                        15740        3718
# 6007            10451       ...                         7413        1368
# 6099             2049       ...                         1200         286
#
#             Unemployment_rate  Median  P25th  P75th  College_jobs  \
# Major_code
# 6000                 0.084186   30500  21000  41000         20792
# 6001                 0.077541   27000  19200  35000          6994
# 6002                 0.075960   31000  22300  42000         13752
# 6003                 0.102197   30000  22000  40000          3849
# 6004                 0.096798   35000  25000  45000         37389
# 6005                 0.105772   32000  22000  42000          7368
# 6007                 0.089552   29000  19200  38300          3948
# 6099                 0.089375   50000  25000  66000           693
#
#             Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 6000                   32725          11880         0.801706
# 6001                   25313          11068         0.836204
# 6002                   28786           9286         0.786074
# 6003                    7635           2840         0.792000
# 6004                   38119          14839         0.806755
# 6005                   20721           5862         0.810944
# 6007                    8707           3586         0.819226
# 6099                    1714            755         0.872455
#
# [8 rows x 21 columns]

# %%
majors[(majors['Major_category'] == 'Business') & (majors['Total'] > 100000)]
# Out:
#             Rank                                   Major     Total       Men  \
# Major_code
# 6200          58                        GENERAL BUSINESS  234590.0  132238.0
# 6201          41                              ACCOUNTING  198633.0   94519.0
# 6203          77  BUSINESS MANAGEMENT AND ADMINISTRATION  329927.0  173809.0
# 6206          78        MARKETING AND MARKETING RESEARCH  205211.0   78857.0
# 6207          36                                 FINANCE  174506.0  115030.0
#
#                Women Major_category  ShareWomen  Sample_size  Employed  \
# Major_code
# 6200        102352.0       Business    0.436302         2380    190183
# 6201        104114.0       Business    0.524153         2042    165527
# 6203        156118.0       Business    0.473190         4212    276234
# 6206        126354.0       Business    0.615727         2684    178862
# 6207         59476.0       Business    0.340825         2189    145696
#
#             Full_time       ...         Full_time_year_round  Unemployed  \
# Major_code                  ...
# 6200           171385       ...                       138299       14946
# 6201           151967       ...                       123169       12411
# 6203           251540       ...                       199897       21502
# 6206           156668       ...                       127230       11663
# 6207           137921       ...                       108595        9413
#
#             Unemployment_rate  Median  P25th  P75th  College_jobs  \
# Major_code
# 6200                 0.072861   40000  30000  55000         29334
# 6201                 0.069749   45000  34000  56000         11417
# 6203                 0.072218   38000  29000  50000         36720
# 6206                 0.061215   38000  30000  50000         25320
# 6207                 0.060686   47000  35000  64000         24243
#
#             Non_college_jobs  Low_wage_jobs  Employment rate
# Major_code
# 6200                  100831          27320         0.810704
# 6201                   39323          10886         0.833331
# 6203                  148395          32395         0.837258
# 6206                   93889          27968         0.871600
# 6207                   48447           9910         0.834905
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercises
#
# #### How many college majors in the sample have a median salary above $50,000?
# * Hint: use `len()` to find the length of a dataframe

# %% [markdown]
# #### How many Business majors have a median salary above $50,000?

# %% [markdown]
# #### Of all Business majors, which has the highest median salary?

# %% [markdown]
# ## Grouping and aggregating data

# %% [markdown]
# We might want to summarize our data by grouping it by major categories
#
# To do this, we will use the `.groupby()` function

# %%
grouped = majors.groupby('Major_category')
grouped

# %%
grouped.groups
# Out:
# {'Agriculture & Natural Resources': Int64Index([1100, 1101, 1102, 1103, 1104, 1105, 1106, 1199, 1302, 1303], dtype='int64', name='Major_code'),
#  'Arts': Int64Index([6000, 6001, 6002, 6003, 6004, 6005, 6007, 6099], dtype='int64', name='Major_code'),
#  'Biology & Life Science': Int64Index([1301, 3600, 3601, 3602, 3603, 3604, 3605, 3606, 3607, 3608, 3609,
#              3611, 3699, 4006],
#             dtype='int64', name='Major_code'),
#  'Business': Int64Index([6200, 6201, 6202, 6203, 6204, 6205, 6206, 6207, 6209, 6210, 6211,
#              6212, 6299],
#             dtype='int64', name='Major_code'),
#  'Communications & Journalism': Int64Index([1901, 1902, 1903, 1904], dtype='int64', name='Major_code'),
#  'Computers & Mathematics': Int64Index([2001, 2100, 2101, 2102, 2105, 2106, 2107, 3700, 3701, 3702, 4005], dtype='int64', name='Major_code'),
#  'Education': Int64Index([2300, 2301, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, 2311,
#              2312, 2313, 2314, 2399, 3501],
#             dtype='int64', name='Major_code'),
#  'Engineering': Int64Index([1401, 2400, 2401, 2402, 2403, 2404, 2405, 2406, 2407, 2408, 2409,
#              2410, 2411, 2412, 2413, 2414, 2415, 2416, 2417, 2418, 2419, 2499,
#              2500, 2501, 2502, 2503, 2504, 2599, 5008],
#             dtype='int64', name='Major_code'),
#  'Health': Int64Index([4002, 6100, 6102, 6103, 6104, 6105, 6106, 6107, 6108, 6109, 6110,
#              6199],
#             dtype='int64', name='Major_code'),
#  'Humanities & Liberal Arts': Int64Index([1501, 2601, 2602, 2603, 3301, 3302, 3401, 3402, 4001, 4801, 4901,
#              5502, 6006, 6402, 6403],
#             dtype='int64', name='Major_code'),
#  'Industrial Arts & Consumer Services': Int64Index([2201, 2901, 3801, 4101, 5601, 5701, 5901], dtype='int64', name='Major_code'),
#  'Interdisciplinary': Int64Index([4000], dtype='int64', name='Major_code'),
#  'Law & Public Policy': Int64Index([3201, 3202, 5301, 5401, 5402], dtype='int64', name='Major_code'),
#  'Physical Sciences': Int64Index([5000, 5001, 5002, 5003, 5004, 5005, 5006, 5007, 5098, 5102], dtype='int64', name='Major_code'),
#  'Psychology & Social Work': Int64Index([5200, 5201, 5202, 5203, 5205, 5206, 5299, 5403, 5404], dtype='int64', name='Major_code'),
#  'Social Science': Int64Index([4007, 5500, 5501, 5503, 5504, 5505, 5506, 5507, 5599], dtype='int64', name='Major_code')}

# %% [markdown]
# To return an *aggregated* dataframe, we need to specify the function we would like pandas to use to aggregate our groups

# %%
grouped.mean()
# Out:
#                                            Rank          Total           Men  \
# Major_category
# Agriculture & Natural Resources      101.500000    8402.222222   4484.111111
# Arts                                 131.125000   44641.250000  16798.750000
# Biology & Life Science                95.357143   32418.714286  13208.500000
# Business                              55.846154  100182.769231  51373.230769
# Communications & Journalism          104.000000   98150.250000  32980.250000
# Computers & Mathematics               57.000000   27182.545455  18975.000000
# Education                            130.375000   34945.562500   6470.375000
# Engineering                           22.620690   18537.344828  14079.551724
# Health                                96.500000   38602.500000   6293.083333
# Humanities & Liberal Arts            135.066667   47564.533333  18189.733333
# Industrial Arts & Consumer Services  105.142857   32827.428571  14825.857143
# Interdisciplinary                    110.000000   12296.000000   2817.000000
# Law & Public Policy                   64.600000   35821.400000  18225.800000
# Physical Sciences                     67.600000   18547.900000   9539.000000
# Psychology & Social Work             143.000000   53445.222222  10901.666667
# Social Science                        91.666667   58885.111111  28537.111111
#
#                                             Women  ShareWomen  Sample_size  \
# Major_category
# Agriculture & Natural Resources       3918.111111    0.405267   110.400000
# Arts                                 27842.500000    0.603658   407.500000
# Biology & Life Science               19210.214286    0.587193   165.500000
# Business                             48809.538462    0.483198  1192.692308
# Communications & Journalism          65170.000000    0.658384  1127.000000
# Computers & Mathematics               8207.545455    0.311772   260.000000
# Education                            28475.187500    0.748507   296.375000
# Engineering                           4457.793103    0.238889   169.862069
# Health                               32309.416667    0.795152   326.166667
# Humanities & Liberal Arts            29374.800000    0.631790   356.000000
# Industrial Arts & Consumer Services  18001.571429    0.349523   309.285714
# Interdisciplinary                     9479.000000    0.770901   128.000000
# Law & Public Policy                  17595.600000    0.483649   387.000000
# Physical Sciences                     9008.900000    0.508683   113.700000
# Psychology & Social Work             42543.555556    0.794397   353.333333
# Social Science                       30348.000000    0.553962   509.000000
#
#                                          Employed     Full_time     Part_time  \
# Major_category
# Agriculture & Natural Resources       6694.300000   5814.300000   1659.100000
# Arts                                 36014.250000  25971.625000  14348.875000
# Biology & Life Science               21628.357143  17169.785714   8338.285714
# Business                             83749.384615  76066.923077  15148.923077
# Communications & Journalism          82665.000000  68332.500000  22454.250000
# Computers & Mathematics              21626.727273  18867.727273   4842.727273
# Education                            29989.937500  24878.687500   7537.062500
# Engineering                          14495.586207  13167.827586   2935.724138
# Health                               31012.250000  24568.250000   9549.333333
# Humanities & Liberal Arts            36274.533333  27795.933333  14268.666667
# Industrial Arts & Consumer Services  27006.142857  21626.142857   8731.714286
# Interdisciplinary                     9821.000000   8032.000000   3173.000000
# Law & Public Policy                  28958.000000  25388.000000   7642.600000
# Physical Sciences                    13923.100000  11285.200000   4344.400000
# Psychology & Social Work             42260.444444  32111.111111  15332.444444
# Social Science                       44610.333333  38571.222222  13507.666667
#
#                                      Full_time_year_round   Unemployed  \
# Major_category
# Agriculture & Natural Resources               4362.600000   382.400000
# Arts                                         19138.875000  3528.500000
# Biology & Life Science                       11843.000000  1632.428571
# Business                                     60801.923077  6144.384615
# Communications & Journalism                  53557.000000  6713.000000
# Computers & Mathematics                      14468.727273  1670.272727
# Education                                    18001.937500  1560.562500
# Engineering                                   9963.862069  1028.172414
# Health                                       19034.833333  1851.083333
# Humanities & Liberal Arts                    19704.066667  3406.733333
# Industrial Arts & Consumer Services          16311.285714  1646.571429
# Interdisciplinary                             6234.000000   749.000000
# Law & Public Policy                          20090.800000  2699.000000
# Physical Sciences                             8563.500000   788.000000
# Psychology & Social Work                     24233.888889  3699.111111
# Social Science                               28357.666667  4775.000000
#
#                                      Unemployment_rate        Median  \
# Major_category
# Agriculture & Natural Resources               0.056328  36900.000000
# Arts                                          0.090173  33062.500000
# Biology & Life Science                        0.060918  36421.428571
# Business                                      0.071064  43538.461538
# Communications & Journalism                   0.075538  34500.000000
# Computers & Mathematics                       0.084256  42745.454545
# Education                                     0.051702  32350.000000
# Engineering                                   0.063334  57382.758621
# Health                                        0.065920  36825.000000
# Humanities & Liberal Arts                     0.081008  31913.333333
# Industrial Arts & Consumer Services           0.048071  36342.857143
# Interdisciplinary                             0.070861  35000.000000
# Law & Public Policy                           0.090805  42200.000000
# Physical Sciences                             0.046511  41890.000000
# Psychology & Social Work                      0.072065  30100.000000
# Social Science                                0.095729  37344.444444
#
#                                             P25th         P75th  College_jobs  \
# Major_category
# Agriculture & Natural Resources      25400.000000  48010.000000   1986.000000
# Arts                                 21962.500000  43662.500000  11848.125000
# Biology & Life Science               26614.285714  46085.714286  10802.357143
# Business                             33461.538462  54846.153846  11426.000000
# Communications & Journalism          26250.000000  44975.000000  21639.000000
# Computers & Mathematics              29290.909091  58090.909091  12532.636364
# Education                            26590.625000  38562.500000  21169.562500
# Engineering                          41555.172414  70448.275862   9302.310345
# Health                               26166.666667  50250.000000  20453.416667
# Humanities & Liberal Arts            23493.333333  42073.333333  12843.333333
# Industrial Arts & Consumer Services  26771.428571  45142.857143   8171.428571
# Interdisciplinary                    25000.000000  44000.000000   5176.000000
# Law & Public Policy                  32640.000000  55000.000000   5844.200000
# Physical Sciences                    28350.000000  57290.000000   7655.200000
# Psychology & Social Work             25333.333333  38777.777778  18256.111111
# Social Science                       28355.555556  50111.111111  12662.222222
#
#                                      Non_college_jobs  Low_wage_jobs  \
# Major_category
# Agriculture & Natural Resources           3449.100000     789.900000
# Arts                                     20465.000000    7514.500000
# Biology & Life Science                    9084.428571    3053.000000
# Business                                 38197.692308    9752.923077
# Communications & Journalism              43248.000000   12398.750000
# Computers & Mathematics                   6769.363636    1466.909091
# Education                                 7610.062500    2554.375000
# Engineering                               3530.448276     864.793103
# Health                                    9208.000000    2605.833333
# Humanities & Liberal Arts                18435.466667    6282.666667
# Industrial Arts & Consumer Services      14945.714286    3798.571429
# Interdisciplinary                         3903.000000    1061.000000
# Law & Public Policy                      20004.800000    4144.000000
# Physical Sciences                         4946.900000    1407.800000
# Psychology & Social Work                 18818.444444    6249.555556
# Social Science                           21138.444444    6020.000000
#
#                                      Employment rate
# Major_category
# Agriculture & Natural Resources             0.860603
# Arts                                        0.815670
# Biology & Life Science                      0.700543
# Business                                    0.829638
# Communications & Journalism                 0.844534
# Computers & Mathematics                     0.799617
# Education                                   0.856697
# Engineering                                 0.787311
# Health                                      0.758078
# Humanities & Liberal Arts                   0.767983
# Industrial Arts & Consumer Services         0.715442
# Interdisciplinary                           0.798715
# Law & Public Policy                         0.770304
# Physical Sciences                           0.776080
# Psychology & Social Work                    0.795633
# Social Science                              0.770296

# %%
grouped['Median'].mean()
# Out:
# Major_category
# Agriculture & Natural Resources        36900.000000
# Arts                                   33062.500000
# Biology & Life Science                 36421.428571
# Business                               43538.461538
# Communications & Journalism            34500.000000
# Computers & Mathematics                42745.454545
# Education                              32350.000000
# Engineering                            57382.758621
# Health                                 36825.000000
# Humanities & Liberal Arts              31913.333333
# Industrial Arts & Consumer Services    36342.857143
# Interdisciplinary                      35000.000000
# Law & Public Policy                    42200.000000
# Physical Sciences                      41890.000000
# Psychology & Social Work               30100.000000
# Social Science                         37344.444444
# Name: Median, dtype: float64

# %%
grouped['Median'].agg(['mean', 'median', 'std', 'count'])
# Out:
#                                              mean  median           std  count
# Major_category
# Agriculture & Natural Resources      36900.000000   35000   6935.416354     10
# Arts                                 33062.500000   30750   7223.164621      8
# Biology & Life Science               36421.428571   36300   4528.912006     14
# Business                             43538.461538   40000   7774.052832     13
# Communications & Journalism          34500.000000   35000   1000.000000      4
# Computers & Mathematics              42745.454545   45000   5108.691346     11
# Education                            32350.000000   32750   3892.728263     16
# Engineering                          57382.758621   57000  13626.079747     29
# Health                               36825.000000   35000   5776.460854     12
# Humanities & Liberal Arts            31913.333333   32000   3393.032076     15
# Industrial Arts & Consumer Services  36342.857143   35000   7290.829204      7
# Interdisciplinary                    35000.000000   35000           NaN      1
# Law & Public Policy                  42200.000000   36000   9066.421565      5
# Physical Sciences                    41890.000000   39500   8251.659766     10
# Psychology & Social Work             30100.000000   30000   5381.914158      9
# Social Science                       37344.444444   38000   4750.555523      9

# %% [markdown]
# A list of built-in aggregatation functions can be found [here](http://pandas.pydata.org/pandas-docs/stable/basics.html#descriptive-statistics)
#
# Pandas provides methods to plot from GroupBy objects

# %%
grouped['Median'].mean().plot(kind='bar', figsize=(10, 8))
plt.show()

# %% [markdown]
# ### Exercise
#
# #### Return the mean of the share of women for each major category and sort from highest to lowest, plot the result as a bar plot

# %% [markdown]
# ## Another plotting library: `seaborn`
#
# * `seaborn` is a plotting library built on top of `matplotlib`
#
# * It is geared towards producing pretty plots for statistical applications
#
# * You can find an example gallery of `seaborn` plots [here](https://seaborn.pydata.org/examples/index.html)

# %%
import seaborn as sns  # Import the package

# %%
sns.lmplot(x="Median", y="ShareWomen", hue="Major_category", height=9, data=majors, fit_reg=False)
plt.xlabel('Median salary')
plt.ylabel('Share of women')
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(x='Major_category', y='Median', data=majors)
plt.xticks(rotation=90)
plt.xlabel('Major category')
plt.show()

# %% [markdown]
# ## Bokeh example
#
# Bokeh is a Python library that makes creating interactive plots super easy - an example gallery is [here](http://bokeh.pydata.org/en/latest/docs/gallery.html)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool, NumeralTickFormatter
from bokeh.palettes import Category20

output_notebook()

# Add title tooltips
hover = HoverTool(tooltips=[
    ("Title", "@Major"),
    ("Share", "$y"),
    ("Median salary", "$x{$0,}")
])


# Create figure
p = figure(tools=[hover, 'pan', 'wheel_zoom'])

# List of majors
majors_list = majors['Major_category'].unique()

# Plot scatter
for major, color in zip(majors_list, Category20[20]):
    
    # Filter data based on major color catergory
    source_major = majors[majors['Major_category'] == major]
    
    # Create data source
    source = ColumnDataSource(source_major[['Major', 'Major_category', 'ShareWomen', 'Median']])
    p.scatter(x='Median', y='ShareWomen', source=source, 
              size=10, legend='Major_category',
              fill_color=color, line_color='grey')

p.legend.click_policy = 'hide'
p.legend.location = "top_right"
p.legend.label_text_font_size = "8pt"
p.xaxis.axis_label = 'Median salary'
p.yaxis.axis_label = 'Share of Women'
p.xaxis[0].formatter = NumeralTickFormatter(format="$0,")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ae7130c9-18cc-4e96-92a2-3a4e6b37d33c"></div>

# %% [markdown]
# ## Other resources
#
# Here are some free, online resources for learning pandas/matplotlib:
#
# * QuantEcon lectures: [Pandas](https://lectures.quantecon.org/py/pandas.html), [Pandas for Panel Data](https://lectures.quantecon.org/py/pandas_panel.html), [Matplotlib](https://lectures.quantecon.org/py/matplotlib.html)
# * QuantEcon [Stata-R-Pandas cheatsheet](https://cheatsheets.quantecon.org/stats-cheatsheet.html)
# * SciPy 2017: [Anatomy of Matplotlib](https://www.youtube.com/watch?v=rARMKS8jE9g)
# * Coursera/University of Michigan: [Introduction to Data Science in Python](https://www.coursera.org/learn/python-data-analysis)
